# %%
import pandas as pd
address="./马蜂窝数据提取.xlsx"
result = []
def excel_one_line_to_list():
    df = pd.read_excel(address, usecols=[11],
                       names=None)  # 读取第一列，不要列名
    df_li = df.values.tolist()

    for s_li in df_li:
        result.append(s_li[0])
    return result

if __name__ == '__main__':
    excel_one_line_to_list()

print(result[218:298])
# Out:
# ['https://m.mafengwo.cn/nb/public/sharejump.php?type=25&uid=17078870', 'https://m.mafengwo.cn/nb/public/sharejump.php?type=25&uid=86237622', 'https://m.mafengwo.cn/nb/public/sharejump.php?type=25&uid=17303238', 'https://m.mafengwo.cn/nb/public/sharejump.php?type=25&uid=45827160', 'https://m.mafengwo.cn/nb/public/sharejump.php?type=25&uid=63310622']

# %%
from selenium import webdriver
import csv
import time

import pandas as pd
address="./马蜂窝数据提取.xlsx"
result = []
def excel_one_line_to_list():
    df = pd.read_excel(address, usecols=[11],
                       names=None)  # 读取第一列，不要列名
    df_li = df.values.tolist()

    for s_li in df_li:
        result.append(s_li[0])
    return result

if __name__ == '__main__':
    excel_one_line_to_list()

# 新建文件保存
csvf = open('./220-300详情数据.csv','a+',encoding='gbk',newline ='')
writer = csv.writer(csvf)
writer.writerow(('a1','a6','a2','a4','a3'))


#实例化一个浏览器对象(传入浏览器的驱动程序)
driver_path = r"E:\chromedriver\chromedriver.exe"    #我将chrome驱动安装的路径
driver = webdriver.Chrome(executable_path = driver_path)


for url in result[218:298]:
    #让浏览器发起一个指定url对应的请求
    driver.get(url)

    time.sleep(5)
    try:
        a1 = driver.find_element_by_xpath('//*[@id="_j_path_number"]/b[3]').text
        a2 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[4]/span[1]/a').text
        a3 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[7]/div[1]/strong/a').text
        a4 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[7]/div[2]/strong/a').text
        a5 = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div/ul/li[2]/a').click()
        time.sleep(6)
        a6 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div[1]/div/div[3]/strong').text
        try:
            writer.writerow((a1,a6,a2,a4,a3))
            print(a1,a6,a2,a4,a3)

        except:
            pass
    except:
        pass

csvf.close()
#     time.sleep(1)
#     driver.quit()  #访问结束，关闭浏览器
# Out:
# 162 0 Lv.10 35 24
# 2262 277542 Lv.45 924 221
# 670 0 Lv.17 24 112
# 20 0 Lv.3 0 12
# 319 23671 Lv.14 31 20
# 1036 8521 Lv.16 14 27
# 604 31313 Lv.22 221 56
# 434 8749 Lv.20 57 62
# 26 1194 Lv.8 0 21
# 10 0 Lv.2 0 7
# 386 12278 Lv.15 9 11
# 415 219952 Lv.33 1206 6
# 12 0 Lv.4 0 1
# 523 8374 Lv.23 166 158
# 140 9327 Lv.8 7 25
# 64 3447 Lv.9 5 10
# 260 0 Lv.33 27 334
# 1803 0 Lv.29 14 112
# 160 5465 Lv.16 13 35
# 1725 121577 Lv.35 453 84
# 5 0 Lv.13 5 42
# 0 0 Lv.14 9 19
# 723 940036 Lv.45 6840 135
# 529 15183 Lv.32 66 980
# 0 0 Lv.17 1185 28
# 101 0 Lv.5 1 15
# 36 0 Lv.3 0 7
# 1112 626 Lv.19 36 86
# 78 6163 Lv.11 6 111
# 2267 22142 Lv.20 62 54
# 45 5123 Lv.9 4 48
# 90 7906 Lv.15 35 182
# 27 876 Lv.6 12 16
# 211 34776 Lv.23 225 80
# 377 33094 Lv.15 23 11
# 16 0 Lv.4 0 10
# 57 16889 Lv.5 11 42
# 1031 56840 Lv.24 127 86
# 536 2944 Lv.17 46 70
# 818 71091 Lv.24 151 17
# 568 969 Lv.19 178 249
# 12 0 Lv.5 14 13
# 3617 16244 Lv.26 367 454
# 0 0 Lv.13 1188 22
# 158 2512 Lv.13 30 9
# 0 0 Lv.15 1192 21
# 2167 88757 Lv.27 464 134
# 0 0 Lv.12 11 21
# 0 0 Lv.18 1182 31
# 0 0 Lv.12 17 21
# 0 0 Lv.18 1200 2683
# 0 0 Lv.19 1192 27
# 0 0 Lv.17 1200 37
# 0 0 Lv.20 1179 2800
# 0 0 Lv.17 9 16
# 0 0 Lv.16 1201 2602
# 0 0 Lv.18 1185 39
# 0 0 Lv.9 1181 31
# 103 3847 Lv.14 7 7
# 0 0 Lv.15 1191 17
# 0 0 Lv.17 1166 28
# 0 0 Lv.18 1193 35
# 958 13776 Lv.24 85 88
# 68 0 Lv.17 13 11
# 500 100752 Lv.23 101 72
# 4484 5068 Lv.25 58 59
# 199 4075 Lv.6 3 16
# 144 7612 Lv.6 1 13
# 821 9898 Lv.18 76 145
# 340 0 Lv.10 6 10
# 665 2029195 Lv.45 12111 1327
# 68 2976 Lv.16 5 22
# 908 26514 Lv.27 519 178
# 951 54999 Lv.33 158 337
# 434 192628 Lv.23 1119 125
# 428 5631 Lv.16 39 45
# 11 0 Lv.19 11 37
# 435 114963 Lv.11 12 17

# %%
import pandas as pd



df = pd.read_excel("./马蜂窝数据提取.xlsx")  # 读取项目名称列,不要列名
df.head()
# Out:
#   HotelName   name                                            content score  \
# 0      和平饭店  小金金天使  上海最具代表性的酒店-奢华与历史底蕴共存\n自从来了上海，天天下雨，非常郁闷。幸好我预订了上...     5
# 1      和平饭店  马蜂窝用户  上海最温暖的酒店～上海和平饭店\n在上海和平饭店与家人团聚，共渡2020新年。和平饭店的历史...     5
# 2      和平饭店   布局圣手                                    看了王大顶才去的。可以 合适。     5
# 3      和平饭店     阳子                                           真不错，环境不错     5
# 4      和平饭店  马蜂窝用户         房间很大。酒店本身就是景点。要去外滩就要住这里。不错。九楼露台可以看外滩夜景，很美。     5
#
#            create_time            （R)最近一次足迹 （F)3年内发表次数  （M）3年内的影响值  用户等级  \
# 0  2020-01-20 00:00:00  2020-01-01 00:00:00          7      8905.0  17.0
# 1  2020-01-02 00:00:00  2020-01-02 00:00:00          1         0.0   1.0
# 2  2019-12-19 00:00:00  2019-12-01 00:00:00         10         0.0   5.0
# 3  2019-10-15 00:00:00  2019-10-15 00:00:00          1         0.0   2.0
# 4  2019-08-30 00:00:00  2019-08-01 00:00:00          2         0.0   1.0
#
#     粉丝数   关注数                                           user_url
# 0  21.0  46.0  https://m.mafengwo.cn/nb/public/sharejump.php?...
# 1   0.0   9.0  https://m.mafengwo.cn/nb/public/sharejump.php?...
# 2   1.0  11.0  https://m.mafengwo.cn/nb/public/sharejump.php?...
# 3   0.0   9.0  https://m.mafengwo.cn/nb/public/sharejump.php?...
# 4   0.0   6.0  https://m.mafengwo.cn/nb/public/sharejump.php?...
