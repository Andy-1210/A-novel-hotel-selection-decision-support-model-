# %%
from selenium import webdriver
import csv
import time

import pandas as pd
address="./马蜂窝数据提取.xlsx"
result = []
def excel_one_line_to_list():
    df = pd.read_excel(address, usecols=[11],
                       names=None)  # 读取第一列，不要列名
    df_li = df.values.tolist()

    for s_li in df_li:
        result.append(s_li[0])
    return result

if __name__ == '__main__':
    excel_one_line_to_list()

# 新建文件保存
csvf = open('./324-400详情数据.csv','a+',encoding='gbk',newline ='')
writer = csv.writer(csvf)
writer.writerow(('a1','a6','a2','a4','a3'))


#实例化一个浏览器对象(传入浏览器的驱动程序)
driver_path = r"E:\chromedriver\chromedriver.exe"    #我将chrome驱动安装的路径
driver = webdriver.Chrome(executable_path = driver_path)


for url in result[322:400]:
    #让浏览器发起一个指定url对应的请求
    driver.get(url)

    time.sleep(5)
    try:
        a1 = driver.find_element_by_xpath('//*[@id="_j_path_number"]/b[3]').text
        a2 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[4]/span[1]/a').text
        a3 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[7]/div[1]/strong/a').text
        a4 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/div[7]/div[2]/strong/a').text
        a5 = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div/ul/li[2]/a').click()
        time.sleep(6)
        a6 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div[1]/div/div[3]/strong').text
        try:
            writer.writerow((a1,a6,a2,a4,a3))
            print(a1,a6,a2,a4,a3)

        except:
            pass
    except:
        pass

csvf.close()
#     time.sleep(1)
#     driver.quit()  #访问结束，关闭浏览器
# Out:
# 0 0 Lv.15 1197 22
# 0 0 Lv.17 1160 33
# 0 0 Lv.20 1185 17
# 0 0 Lv.10 1192 27
# 0 0 Lv.17 1199 27
# 0 0 Lv.17 6 20
# 0 0 Lv.17 4 20
# 0 0 Lv.11 1170 20
# 0 0 Lv.19 1181 3001
# 0 0 Lv.22 1281 363
# 0 0 Lv.18 7 21
# 0 0 Lv.18 14 20
# 0 0 Lv.18 1208 37
# 0 0 Lv.18 1189 32
# 0 0 Lv.18 1209 2793
# 0 0 Lv.17 1206 2847
# 0 0 Lv.9 14 22
# 0 0 Lv.18 1200 2832
# 0 0 Lv.17 1195 25
# 0 0 Lv.15 1193 39
# 0 0 Lv.17 16 14
# 0 0 Lv.14 1182 26
# 0 0 Lv.11 15 18
# 0 0 Lv.17 1180 27
# 0 0 Lv.17 1176 2691
# 393 267662 Lv.39 2178 463
# 11 6497 Lv.3 1 2
# 0 0 Lv.17 1483 2025
# 20 18677 Lv.8 4 16
# 0 0 Lv.20 1213 2875
# 29 47559 Lv.14 93 9
# 181 618225 Lv.27 374 340
# 1 1191 Lv.3 1 22
# 5 0 Lv.9 8 40
# 18 20037 Lv.13 27 48
# 0 0 Lv.18 1190 31
# 21 926525 Lv.37 1329 28
# 0 0 Lv.18 1197 2467
# 0 0 Lv.11 1188 31
# 0 0 Lv.17 9 26
# 0 0 Lv.15 1204 2341
# 0 0 Lv.15 1178 26
# 0 0 Lv.17 1190 2446
# 0 0 Lv.18 1175 29
# 0 0 Lv.16 1179 15
# 0 0 Lv.13 1179 20
# 0 0 Lv.16 1181 20
# 0 0 Lv.9 1174 35
# 0 0 Lv.15 11 20
# 0 0 Lv.12 7 26
# 0 0 Lv.16 1165 24
# 0 0 Lv.18 1162 26
# 0 0 Lv.15 1196 24
# 0 0 Lv.17 1181 21
# 0 0 Lv.15 1177 37
# 0 0 Lv.15 1174 18
# 0 0 Lv.18 1196 2809
# 0 0 Lv.17 1157 2740
# 0 0 Lv.15 1185 34
# 0 0 Lv.20 1171 25
# 0 0 Lv.12 1200 2678
# 0 0 Lv.15 1191 16
# 0 0 Lv.18 1186 28
# 0 0 Lv.16 1189 27
# 0 0 Lv.18 21 35
# 0 0 Lv.18 1164 2443
# 0 0 Lv.17 9 19
# 0 0 Lv.17 10 22
# 0 0 Lv.20 1211 2661
# 0 0 Lv.17 1189 18
# 0 0 Lv.19 1160 30
# 0 0 Lv.15 17 25
# 0 0 Lv.18 1184 25
# 0 0 Lv.9 1162 23
# 0 0 Lv.18 1176 19
